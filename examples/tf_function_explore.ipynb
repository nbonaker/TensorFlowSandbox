# %%
import numpy as np
import tensorflow as tf

# %%
tf.compat.v1.disable_eager_execution() 

# Define computational graph
X = tf.constant(1., name='Y')
Y = tf.Variable(initial_value=tf.zeros([]), name='Y')
assign_op = Y.assign(X, name='assign_op')


# Add an op to initialize the variables.
init_op = tf.compat.v1.global_variables_initializer()

with tf.compat.v1.Session() as sess:
    def print_all():
        print("X:", X)
        print("Y:", Y)
        print("sess.run(Y):", sess.run(Y))
        print("sess.run(X):", sess.run(X))

    print('---------------------')
    try:
        print_all()
    except Exception as err:
        print(err)

    print('---------------------')
    sess.run(init_op)
    print_all()
    
    print('---------------------')
    sess.run(assign_op)
    print_all()
# Out:
# ---------------------
# X: Tensor("Y_10:0", shape=(), dtype=float32)
# Y: <tf.Variable 'Y_11:0' shape=() dtype=float32>
# Error while reading resource variable Y_11 from Container: localhost. This could mean that the variable was uninitialized. Not found: Container localhost does not exist. (Could not find resource: localhost/Y_11)
# 	 [[node Y_11/Read/ReadVariableOp (defined at <ipython-input-8-98754fdc8440>:5) ]]
#
# Original stack trace for 'Y_11/Read/ReadVariableOp':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3242, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-98754fdc8440>", line 5, in <module>
#     Y = tf.Variable(initial_value=tf.zeros([]), name='Y')
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 261, in __call__
#     return cls._variable_v2_call(*args, **kwargs)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 255, in _variable_v2_call
#     shape=shape)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 236, in <lambda>
#     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py", line 2647, in default_variable_creator_v2
#     shape=shape)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 263, in __call__
#     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py", line 1434, in __init__
#     distribute_strategy=distribute_strategy)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py", line 1617, in _init_from_args
#     value = gen_resource_variable_ops.read_variable_op(handle, dtype)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py", line 483, in read_variable_op
#     "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3327, in _create_op_internal
#     op_def=op_def)
#   File "/home/rgiordan/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1791, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ---------------------
# X: Tensor("Y_10:0", shape=(), dtype=float32)
# Y: <tf.Variable 'Y_11:0' shape=() dtype=float32>
# sess.run(Y): 0.0
# sess.run(X): 1.0
# ---------------------
# X: Tensor("Y_10:0", shape=(), dtype=float32)
# Y: <tf.Variable 'Y_11:0' shape=() dtype=float32>
# sess.run(Y): 1.0
# sess.run(X): 1.0
